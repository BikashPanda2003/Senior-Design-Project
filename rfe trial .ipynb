# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset_full.csv')

# %%
df.head()
# Out:
#    qty_dot_url  qty_hyphen_url  qty_underline_url  qty_slash_url  \
# 0            3               0                  0              1
# 1            5               0                  1              3
# 2            2               0                  0              1
# 3            4               0                  2              5
# 4            2               0                  0              0
#
#    qty_questionmark_url  qty_equal_url  qty_at_url  qty_and_url  \
# 0                     0              0           0            0
# 1                     0              3           0            2
# 2                     0              0           0            0
# 3                     0              0           0            0
# 4                     0              0           0            0
#
#    qty_exclamation_url  qty_space_url  ...  qty_ip_resolved  qty_nameservers  \
# 0                    0              0  ...                1                2
# ...

# %%
df['qty_at_url']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 88642    0
# 88643    0
# 88644    0
# 88645    0
# 88646    0
# Name: qty_at_url, Length: 88647, dtype: int64

# %%
df.corr()
# Out:
#                       qty_dot_url  qty_hyphen_url  qty_underline_url  \
# qty_dot_url              1.000000        0.109737           0.127851
# qty_hyphen_url           0.109737        1.000000           0.213589
# qty_underline_url        0.127851        0.213589           1.000000
# qty_slash_url            0.246201        0.304762           0.246653
# qty_questionmark_url     0.409549        0.061247           0.067009
# ...                           ...             ...                ...
# qty_redirects           -0.051842       -0.001930          -0.013864
# url_google_index        -0.004035       -0.002939          -0.001823
# domain_google_index     -0.002490        0.006875           0.003421
# url_shortened           -0.059222       -0.010346          -0.012158
# phishing                 0.171128        0.200382           0.191151
#
#                       qty_slash_url  qty_questionmark_url  qty_equal_url  \
# ...

# %%
status = df.corr()['phishing']
status
# Out:
# qty_dot_url             0.171128
# qty_hyphen_url          0.200382
# qty_underline_url       0.191151
# qty_slash_url           0.699061
# qty_questionmark_url    0.111694
#                           ...
# qty_redirects          -0.061775
# url_google_index       -0.008986
# domain_google_index     0.000794
# url_shortened           0.099250
# phishing                1.000000
# Name: phishing, Length: 112, dtype: float64

# %%
def select_feature(dataf, thres):
    selected = []
    i = 0
    for score in dataf:
        if abs(score) > thres:
            selected.append(dataf.index[i])
        i += 1
    return selected

# %%
features_selected = select_feature(status, 0.2)
features_selected
# Out:
# ['qty_hyphen_url',
#  'qty_slash_url',
#  'qty_equal_url',
#  'qty_tld_url',
#  'length_url',
#  'qty_dot_domain',
#  'qty_dot_directory',
#  'qty_hyphen_directory',
#  'qty_underline_directory',
#  'qty_slash_directory',
#  'qty_questionmark_directory',
#  'qty_equal_directory',
#  'qty_at_directory',
#  'qty_and_directory',
#  'qty_exclamation_directory',
#  'qty_space_directory',
#  'qty_tilde_directory',
#  'qty_comma_directory',
#  'qty_plus_directory',
#  'qty_asterisk_directory',
#  'qty_hashtag_directory',
#  'qty_dollar_directory',
#  'qty_percent_directory',
#  'directory_length',
#  'qty_dot_file',
#  'qty_hyphen_file',
#  'qty_underline_file',
#  'qty_slash_file',
#  'qty_questionmark_file',
#  'qty_equal_file',
#  'qty_at_file',
#  'qty_and_file',
#  'qty_exclamation_file',
#  'qty_space_file',
#  'qty_tilde_file',
#  'qty_comma_file',
#  'qty_plus_file',
#  'qty_asterisk_file',
#  'qty_hashtag_file',
#  'qty_dollar_file',
#  'qty_percent_file',
#  'file_length',
# ...

# %%
len(features_selected)
# Out:
# 63

# %%
selected_features = [i for i in features_selected if i != 'phishing']
selected_features
# Out:
# ['qty_hyphen_url',
#  'qty_slash_url',
#  'qty_equal_url',
#  'qty_tld_url',
#  'length_url',
#  'qty_dot_domain',
#  'qty_dot_directory',
#  'qty_hyphen_directory',
#  'qty_underline_directory',
#  'qty_slash_directory',
#  'qty_questionmark_directory',
#  'qty_equal_directory',
#  'qty_at_directory',
#  'qty_and_directory',
#  'qty_exclamation_directory',
#  'qty_space_directory',
#  'qty_tilde_directory',
#  'qty_comma_directory',
#  'qty_plus_directory',
#  'qty_asterisk_directory',
#  'qty_hashtag_directory',
#  'qty_dollar_directory',
#  'qty_percent_directory',
#  'directory_length',
#  'qty_dot_file',
#  'qty_hyphen_file',
#  'qty_underline_file',
#  'qty_slash_file',
#  'qty_questionmark_file',
#  'qty_equal_file',
#  'qty_at_file',
#  'qty_and_file',
#  'qty_exclamation_file',
#  'qty_space_file',
#  'qty_tilde_file',
#  'qty_comma_file',
#  'qty_plus_file',
#  'qty_asterisk_file',
#  'qty_hashtag_file',
#  'qty_dollar_file',
#  'qty_percent_file',
#  'file_length',
# ...

# %%
X_selected = df[selected_features]
X_selected
# Out:
#        qty_hyphen_url  qty_slash_url  qty_equal_url  qty_tld_url  length_url  \
# 0                   0              1              0            1          25
# 1                   0              3              3            3         223
# 2                   0              1              0            1          15
# 3                   0              5              0            1          81
# 4                   0              0              0            1          19
# ...               ...            ...            ...          ...         ...
# 88642               1              0              0            2          23
# 88643               0              0              0            1          34
# 88644               1              5              0            1          70
# 88645               0              1              0            1          28
# 88646               0              0              0            1          16
#
# ...

# %%
y = df['phishing']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 88642    0
# 88643    0
# 88644    1
# 88645    1
# 88646    0
# Name: phishing, Length: 88647, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.30, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(LR,n_features_to_select=5)

# %%
X_selected
# Out:
#        qty_hyphen_url  qty_slash_url  qty_equal_url  qty_tld_url  length_url  \
# 0                   0              1              0            1          25
# 1                   0              3              3            3         223
# 2                   0              1              0            1          15
# 3                   0              5              0            1          81
# 4                   0              0              0            1          19
# ...               ...            ...            ...          ...         ...
# 88642               1              0              0            2          23
# 88643               0              0              0            1          34
# 88644               1              5              0            1          70
# 88645               0              1              0            1          28
# 88646               0              0              0            1          16
#
# ...

# %%
rfe.fit(X_selected_std,y)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
final_feature = X_selected.columns[rfe.support_]
final_feature
# Out:
# Index(['qty_slash_directory', 'qty_at_directory', 'qty_comma_file',
#        'tld_present_params', 'time_domain_activation'],
#       dtype='object')

# %%
len(rfe.support_)
# Out:
# 62

# %% [raw]
#  temp = df.drop('phishing', axis=1)

# %%
temp = X_selected.columns[rfe.support_]
temp
# Out:
# Index(['qty_slash_directory', 'qty_at_directory', 'qty_comma_file',
#        'tld_present_params', 'time_domain_activation'],
#       dtype='object')

# %%
X = df[temp]
X
# Out:
#        qty_slash_directory  qty_at_directory  qty_comma_file  \
# 0                        1                 0               0
# 1                        3                 0               0
# 2                        1                 0               0
# 3                        5                 0               0
# 4                       -1                -1              -1
# ...                    ...               ...             ...
# 88642                   -1                -1              -1
# 88643                   -1                -1              -1
# 88644                    5                 0               0
# 88645                    1                 0               0
# 88646                   -1                -1              -1
#
#        tld_present_params  time_domain_activation
# 0                      -1                      -1
# 1                       0                     579
# 2                      -1                      -1
# ...

# %%
LR.fit(X_train_std,y_train)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
pred = LR.predict(X_test_std)

# %%
accuracy_score(pred,y_test)
# Out:
# 0.9197217522090618

# %%
from sklearn.feature_selection import fisher_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 from sklearn.feature_selection import fisher_score
#
# ImportError: cannot import name 'fisher_score' from 'sklearn.feature_selection' (C:\ProgramData\anaconda3\lib\site-packages\sklearn\feature_selection\__init__.py)

# %%
from sklearn.preprocessing import StandardScaler

# %%
SC = StandardScaler()

# %%
X_selected_std = SC.fit_transform(X_selected)
X_train_std =  SC.fit_transform(X_train)
X_test_std = SC.fit_transform(X_test)

# %%
len(X_train_std)
# Out:
# 62052

# %%
X = df.drop('phishing',axis=1)

# %%
X
# Out:
#        qty_dot_url  qty_hyphen_url  qty_underline_url  qty_slash_url  \
# 0                3               0                  0              1
# 1                5               0                  1              3
# 2                2               0                  0              1
# 3                4               0                  2              5
# 4                2               0                  0              0
# ...            ...             ...                ...            ...
# 88642            3               1                  0              0
# 88643            2               0                  0              0
# 88644            2               1                  0              5
# 88645            2               0                  0              1
# 88646            2               0                  0              0
#
#        qty_questionmark_url  qty_equal_url  qty_at_url  qty_and_url  \
# 0                         0              0           0            0
# ...

# %%
y = df['phishing']
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 88642    0
# 88643    0
# 88644    1
# 88645    1
# 88646    0
# Name: phishing, Length: 88647, dtype: int64

# %%
X_std = SC.fit_transform(X)

# %%
rfe = RFE(LR,n_features_to_select=5)

# %%
rfe.fit(X_std,y)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
final_feature = X.columns[rfe.support_]
final_feature
# Out:
# Index(['qty_at_url', 'qty_slash_directory', 'qty_equal_directory',
#        'qty_exclamation_directory', 'qty_comma_file'],
#       dtype='object')

# %%
temp = X.columns[rfe.support_]
temp
# Out:
# Index(['qty_at_url', 'qty_slash_directory', 'qty_equal_directory',
#        'qty_exclamation_directory', 'qty_comma_file'],
#       dtype='object')

# %%
X_yz = df[temp]
X_yz
# Out:
#        qty_at_url  qty_slash_directory  qty_equal_directory  \
# 0               0                    1                    0
# 1               0                    3                    0
# 2               0                    1                    0
# 3               0                    5                    0
# 4               0                   -1                   -1
# ...           ...                  ...                  ...
# 88642           0                   -1                   -1
# 88643           0                   -1                   -1
# 88644           0                    5                    0
# 88645           0                    1                    0
# 88646           0                   -1                   -1
#
#        qty_exclamation_directory  qty_comma_file
# 0                              0               0
# 1                              0               0
# 2                              0               0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_yz, y, test_size=0.30, random_state=42)

# %%
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred = LR.predict(X_test)

# %%
accuracy_score(pred,y_test)
# Out:
# 0.8672682835119383

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
classification_report(pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.81      0.98      0.89     14359\n           1       0.98      0.73      0.83     12236\n\n    accuracy                           0.87     26595\n   macro avg       0.89      0.86      0.86     26595\nweighted avg       0.89      0.87      0.86     26595\n'

# %%
confusion_matrix(pred,y_test)
# Out:
# array([[14139,   220],
#        [ 3310,  8926]], dtype=int64)
